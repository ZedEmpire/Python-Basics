# %%
#1 Write a Python program to print "Hello, World!

    - print("Hello World")

#2 write a python program that display your name and age

    - name = ("Zareef Ahmad")
    - age = 30
    - print(name, "-", age)

#3 write a program that check if a given word is a python keyword

    - import keyword
    - print(keyword.kwlist)

#4 Write code to print all the pre-defined keywords in Python using the keyword library

    - import keyword

    #Python keywords
      keywords = keyword.kwlist

      print("Python Keywords:")
      for kw in keywords:
        print(kw)
#5 Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each

    - # Creating a list
      list = [1, 2, 3, 4, 5]
      print("Original list:", list)

      # Modifying an element in the list
      list1[2] = 30
      print("Modified list:", list1)  # This works because lists are mutable

      # Creating a tuple
      tuple = (1, 2, 3, 4, 5)
      print("\nOriginal tuple:", tuple)

      # Tuples are immutable, cant be change or add anything


#6 Write a function to demonstrate the behavior of mutable and immutable arguments


    def demonstrate_mutable_immutable(immutable_arg, mutable_arg):
       print("Before modification:")
       print(f"Immutable argument (int): {immutable_arg}")
       print(f"Mutable argument (list): {mutable_arg}")

    # Trying to modify immutable argument
    immutable_arg += 10  # This creates a new integer object

    # Trying to modify mutable argument
    mutable_arg.append(10)  # This modifies the existing list

#8 Write a program to demonstrate the use of logical operators

    def logical_operators_demo():
    a = True
    b = False

    print(f"a = {a}, b = {b}\n") #False

    Both condition must be True

#9 Write a Python program to convert user input from string to integer, float, and boolean types

    # Taking user input as a string
    user_input = input("Enter a value: ")

    # Converting to integer and Float
        print("Cannot convert to integer and float")

    # Converting to boolean
    bool_value = bool(user_input)  # Any non-empty string converts to True
    print("Boolean value:", bool_value)

#11 Write a program that checks if a number is positive, negative, or zero

    - #user input
      num = int(input("Enter a number: "))

      if num > 0:
          print("Positive.")
      elif num < 0:
          print("Negative.")
      else:
          print("Zero.")


#12 Write a for loop to print numbers from 1 to 100

    for i in range(1,100):
      print(i)

#13 Write a Python program to find the sum of all even numbers between 1 and 500

    sum = 0
    for i in range(1,50):
      if i % 2 == 0:
         sum += i
    print(sum)
# Out:
# Zareef Ahmad - 30

# %% [markdown]
# """Q1. What is Python, and why is it popular ?
#
#     - Python is a programming language that's popular because it's easy to learn, versatile, and can be used for many different purposes.
#
# Q2. What is an interpreter in Python ?
#
#     - A Python interpreter is a program that reads and executes Python code. It translates Python code into bytecode, which is then executed by the Python Virtual Machine (PVM).
#
# Q3. What are pre-defined keywords in Python ?
#
#     - Predefined keywords in Python are words with special meanings that are part of the Python syntax. They cannot be changed and cannot be used as identifiers like variable or function names.
#
# Q4. Can keywords be used as variable names
#
#     - NO, keyword cannot be use as veriable names because they have special meanings and purposes in the programming language.
#
# Q5. What is mutability in Python ?
#
#     - mutability is the ability of an object to be changed after it has been created.
#
# Q6. Why are lists mutable, but tuples are immutable ?
#
#     - lists are mutable to allow for flexibility in modifying their contents, while tuples are immutable to ensure data integrity and memory optimization.
#
# Q7. What is the difference between “==” and “is” operators in Python ?
#
#     - The == operator checks value equality. It compares the contents of two objects to see if they are the same.
#
#     - The is operator checks identity equality. It compares whether two objects refer to the same object in memory (i.e., if they are the same instance).
#
# Q8. What are logical operators in Python ?
#
#     - logical operators are used to combine conditional statements or to evaluate boolean expressions. They return True or False based on the evaluation of the expressions they are applied to.
#     > there are tow main logincal operetors
#       - AND
#       - OR
#
# Q9. What is type casting in Python ?
#
#     - Type casting in Python refers to the process of converting one data type to another.
#     > there are two types of type casting
#       - implicit type casting
#       - explicit type casting
#
# Q10. What is the difference between implicit and explicit type casting ?
#
#     > Implicit Type Casting is automatic and happens when Python can safely convert data types without risk of data loss (e.g., integer to float).
#     > Explicit Type Casting is manual and done by the programmer using functions like int(), float(), etc., to control the conversion and potentially handle cases where data loss may occur (e.g., converting float to int).
#
# Q11. What is the purpose of conditional statements in Python ?
#
#     - Conditional statements in Python are used to control the flow of execution based on certain conditions. They allow the program to make decisions and execute specific blocks of code depending on whether a condition is True or False. This makes programs dynamic and able to react to different inputs, situations, or states.
#
# Q12. How does the elif statement work ?
#
#     - when you want to check multiple conditions, one after another.
#      The elif statement comes after an if statement and before the else statement, making it part of a chain of conditions.
#
# Q13. What is the difference between for and while loops ?
#
#     > for loop: Best when the number of iterations is known or you are iterating over a fixed sequence.
#     > while loop: Best when the number of iterations is unknown and the loop depends on a condition.
# """
